# %%
import pandas as pd
df = pd.read_csv('../report/union_data.csv')
brasil_df = df[df["empresa"] == "Brasil"]
brasil_df
# Out:
#       plataforma operador empresa                    username    month  \
# 0       Netrefer   BetMGM  Brasil               TipsterpageBR  2026-05
# 12      Netrefer    Stake  Brasil            AfiliagamblingBR  2026-05
# 27      Netrefer  BetFair  Brasil               TipsterpageBR  2026-05
# 46    Raventrack  Novibet  Brasil  affiliabetbrasil@gmail.com  2026-05
# 47    Raventrack  Novibet  Brasil  afiliagamblingmx@gmail.com  2026-05
# 51    Raventrack  Novibet  Brasil     infoafiliawin@gmail.com  2026-05
# 59     Cellxpert    Blaze  Brasil               Afiliagamling  2026-05
# 74  IncomeAccess   Betano  Brasil               TipsterpageBR  2026-05
# 75  IncomeAccess   F12Bet  Brasil             Afilia_Gambling  2026-05
#
#    currency     vendor_name  rs_operador  cpa_operador
# 0       BRL             NaN       379.71          0.00
# 12      BRL             NaN       154.30          0.00
# 27      BRL             NaN        56.62      11764.66
# ...
